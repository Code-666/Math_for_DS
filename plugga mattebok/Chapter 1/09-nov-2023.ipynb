# %% [markdown]
# ### Number Theory

# %% [markdown]
# Natural numbers: 1, 2, 3, 4, 5.... and so on. Only positive numbers
#
# Whole numbers: adds "0". Numbers greater then 9 : "10", "1000", "1090"
#
# Integers: Includes both positive and negative numbers also includes "0"
#
# rational numbers: numbers you can express as fractions like 2/3
#
# irrational numbers: number that cant be  expressed as fractions, for example: pi, squar root of 2 and eulers number
#
# Real numbers: includes both rational and irrational numbers
#
# Complex and imaginary numbers: encountered when taiking the square root a negative number. will mostly stay clear of them in this book.

# %% [markdown]
# ### Order of Operations

# %% [markdown]
# parentheses, exponents, multiplications, divisions, addition and subtraction

# %%
2 * (3+2)**2 / 5 - 4
# Out:
# 6.0

# %%
2 * (5)**2 / 5 - 4
# Out:
# 6.0

# %%
2 * 25 / 5 - 4
# Out:
# 6.0

# %%
50 / 5 - 4
# Out:
# 6.0

# %%
10 - 4
# Out:
# 6

# %% [markdown]
# ### Variables

# %% [markdown]
# In math: A named place holder for an unspecified or unknown number

# %%
x = int(input("Number: "))
product = 3 * x
print(F"3 * {x} = {product}")
# Out:
# Number: 4
# 3 * 4 = 12

# %%
beta = 1.75
theta = 30.0

# %%
x1 = 3
x2 = 10
x3 = 44

# %% [markdown]
# ### functions

# %% [markdown]
# Defines relationships between two or more variables
#
# input variable (also domain variables or independent variables)
# plugs into an expression
#
# results in a output variable (also dependent variable)

# %% [markdown]
# rather than this: y = 2x + 1
#
# can also be expressed as: f(x) = 2x + 1

# %%
def f(x):
    return 2 * x + 1

x_values = [0, 1, 2, 3]

for x in x_values:
    y = f(x)
    print(y)
# Out:
# 1
# 3
# 5
# 7

# %% [markdown]
# y = 2x + 1 is a continuous function

# %%
from sympy import *

x = symbols('x')
f = 2*x + 1
plot(f)

# %%
x = symbols('x')
f = x**2 + 1
plot(f)

# %%
from sympy.plotting import plot3d

x, y = symbols('x y')
f = 2*x + 3*y
plot3d(f)

# %% [markdown]
# ### Stopped before the "Summations" section
