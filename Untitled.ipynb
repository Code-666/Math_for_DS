# %% [markdown]
# # Essential Maths for Data Science - Chapter 1

# %% [markdown]
# ### Order of Operations

# %%
# Expression
2 * (3+2)**2 / 5 - 4

# Parentheses
2 * 5**2 / 5 - 4

# Exponent
2 * 25 / 5 - 4

# multiplication and division
50 / 5 - 4

# addition and subtraction
10 - 4
# Out:
# 6

# %%
my_value = 2 * (3 + 2)**2 / 5 - 4
print(my_value)
# Out:
# 6.0

# %%
my_value = 2 * ((3 + 2)**2 / 5) - 4
print(my_value)
# Out:
# 6.0

# %% [markdown]
# ### Variable

# %%
x = int(input('Please input a number\n'))

product = 3 * x
expression = f'3 * {x} ='

print(expression, product)
# Out:
# Please input a number
# 3
# 3 * 3 = 9

# %%
# Greek variable names in code
beta = 1.75
theta = 30.0

# %%
# Expressing subscripted variables
x1 = 3 # or x_1 = 3
x2 = 10 # or x_2 = 10
x3 = 44 # or x_3 = 44

# %%
# Declaring a linear function
def f(x):
    return 2 * x + 1

x_values = [0, 1, 2, 3]

for x in x_values:
    y = f(x)
    print(y)
# Out:
# 1
# 3
# 5
# 7

# %%
# Charting a linear function 

from sympy import *

x = symbols('x')
f = 2*x + 1
plot(f)

# %%
# Charting an exponential function

from sympy import *

x = symbols('x')
f = x**2 + 1
plot(f)

# %%
# Declaring a function with two independent variables

from sympy import *
from sympy.plotting import plot3d

x, y = symbols('x y')
f = 2*x + 3*y
plot3d(f)

# %% [markdown]
# ### Summations

# %%
# Performing a summation in Python

summation = sum(2*i for i in range(1,6))
print(summation)
# Out:
# 30

# %%
# Summation of elements

x = [1, 4, 6, 2]
n = len(x)

summation = sum(10*x[i] for i in range(0,n))

print(summation)
# Out:
# 130

# %%
from sympy import *

i,n = symbols('i n')

# iterate each element i from 1 to n
# then muliply and sum
summation = Sum(2*i,(i,1,5))

# specify n as 5,
# iterating the numbers 1 through 5
up_to_5 = summation.subs(n, 5)
print(up_to_5.doit()) # 30

# also
summation = Sum(2*i,(i,1,5))
print(summation.doit())
# Out:
# 30
# 30

# %% [markdown]
# ### Exponents

# %%
from sympy import *

x = symbols('x')
expr = x**2 / x**5
print(expr) # x**(-3)
# Out:
# x**(-3)
